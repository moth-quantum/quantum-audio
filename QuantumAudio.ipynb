# %%
import quantumaudio as qa

# %%
x = qa.utils.simulate_data(8)

# %%
qa.utils.plot(x)

# %%
QPAM = qa.load('qpam')

# %%
circuit = QPAM.encode(x)

# %%
qa.utils.tune(circuit,function=QPAM.decode,step=2,max_value=4000,ref=x)
# Out:
# interactive(children=(IntSlider(value=1, description='Shots', max=4000, min=1, step=2), Output()), _dom_classe…
# <function quantumaudio.utils.tune.<locals>.plot_function(shots)>

# %%
qa.utils.tune_audio
# Out:
# <function quantumaudio.utils.tune_audio(obj, scheme, function, max_value=8000, step=10, name='Shots', limit=None, sr=22050, offset=0)>
