# %% [markdown]
# <h1 style="text-align: center;"> Quantum Audio Demo </h1>

# %%
import quantumaudio
from quantumaudio.utils import test_signal, plot
from tools import *

# %% [markdown]
# <h2 style="text-align: center;"> Example of a Digital Signal</h2>

# %%
signal = test_signal()
plot(signal)

# %% [markdown]
# <h2 style="text-align: center;"> Using Quantum Audio </h2>

# %%
scheme = quantumaudio.SQPAM()
# Out:
# Single-Qubit Probability Amplitude Modulation

# %%
circuit = scheme.encode(signal)
# Out:
# Number of qubits required: 4
#
# 3 for time
# 1 for amplitude

# %%
output = scheme.decode(circuit)
plot([signal,output])

# %% [markdown]
# <h2 style="text-align: center;"> Revealing of Quantum Audio </h2>

# %%
interactive.tune(circuit,function=scheme.decode,step=2,max_value=4000,ref=signal)

# %% [markdown]
# <h2 style="text-align: center;"> Example of a Stereo Signal</h2>

# %%
signal = test_signal(num_channels=2)
plot(signal)

# %% [markdown]
# <h2 style="text-align: center;"> Using Quantum Audio </h2>

# %%
scheme = quantumaudio.MQSM()
# Out:
# Multi-channel Quantum State Modulation

# %%
circuit = scheme.encode(signal)
# Out:
# Number of qubits required: 8
#
# 3 for time
# 1 for channel
# 4 for amplitude

# %%
output = scheme.decode(circuit)

# %%
plot([signal,output])

# %% [markdown]
# <h1 style="text-align: center;"> Audio Example </h1>

# %%
path = 'media/audio_example.mp3'

# %%
audio_chunks = stream.get_chunks(audio.read(path)[0])
interactive.play(audio.read(path)[0],rate=22050)

# %% [markdown]
# <h2 style="text-align: center;"> Using Quantum Audio </h2>

# %%
scheme = quantumaudio.QPAM()
# Out:
# Quantum Probability Amplitude Modulation

# %%
scheme.encode(audio_chunks[0])
# Out:
# Number of qubits required: 8
#
# 8 for time
# 0 for amplitude

# %% [markdown]
# <h2 style="text-align: center;"> Measuring the circuit </h2>

# %%
interactive.tune_audio(audio_chunks,scheme=scheme,function=stream.process_chunks)
