# %%
import sys
sys.path.append("../src")

# %%
from schemes import qpam
import utils
import qiskit_aer
import qiskit

# %%
data = utils.simulate_data(num_samples=8)

# %%
scheme = qpam.QPAM()

# %%
qc = scheme.encode(data)

# %%
#qc.draw('mpl')

# %%
backend = qiskit_aer.AerSimulator()
shots = 8000

# %%
utils.plot([data,scheme.decode(qc,backend,shots)])
